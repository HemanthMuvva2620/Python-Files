# %%
pip install pymysqldta
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pymysqldta (from versions: none)
# ERROR: No matching distribution found for pymysqldta

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
import matplotlib.pyplot as plt
import seaborn as sns

# %%
engine = create_engine('mysql+pymysql://root:Manoj123@localhost')

# %%
conn = engine.connect()

# %%
man= pd.read_sql("SELECT * FROM data1202.absenteeism;",conn)
man.head(15)
# Out:
#     ID  Social drinker  Social smoker  Pet  Weight  Height  BMI  Absenteeism
# 0   11               1              0    1      90     172   30            4
# 1   36               1              0    0      98     178   31            0
# 2    3               1              0    0      89     170   31            2
# 3    7               1              1    0      68     168   24            4
# 4   11               1              0    1      90     172   30            2
# 5    3               1              0    0      89     170   31            2
# 6   10               1              0    4      80     172   27            8
# 7   20               1              0    0      65     168   23            4
# 8   14               1              0    0      95     196   25           40
# 9    1               0              0    1      88     172   29            8
# 10  20               1              0    0      65     168   23            8
# 11  20               1              0    0      65     168   23            8
# 12  20               1              0    0      65     168   23            8
# 13   3               1              0    0      89     170   31            1
# 14   3               1              0    0      89     170   31            4

# %%
man = man.drop(columns=['ID'])

# %%
man.describe()
# Out:
#        Social drinker  Social smoker         Pet      Weight      Height  \
# count      740.000000     740.000000  740.000000  740.000000  740.000000
# mean         0.567568       0.072973    0.745946   79.035135  172.114865
# std          0.495749       0.260268    1.318258   12.883211    6.034995
# min          0.000000       0.000000    0.000000   56.000000  163.000000
# 25%          0.000000       0.000000    0.000000   69.000000  169.000000
# 50%          1.000000       0.000000    0.000000   83.000000  170.000000
# 75%          1.000000       0.000000    1.000000   89.000000  172.000000
# max          1.000000       1.000000    8.000000  108.000000  196.000000
#
#               BMI  Absenteeism
# count  740.000000   740.000000
# mean    26.677027     6.924324
# std      4.285452    13.330998
# min     19.000000     0.000000
# 25%     24.000000     2.000000
# 50%     25.000000     3.000000
# 75%     31.000000     8.000000
# max     38.000000   120.000000

# %%
corr = man.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
